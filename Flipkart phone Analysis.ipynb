# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Mobiles_Dataset.csv")

# %%
df.head()
# Out:
#                          Product Name Actual price Discount price  Stars  \
# 0     Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1      Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2     Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3  OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4  OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
#
#            Rating        Reviews RAM (GB) Storage (GB)  Display Size (inch)  \
# 0  44,793 Ratings  2,402 Reviews      NIL          128                 6.10
# 1  44,793 Ratings  2,402 Reviews      NIL          128                 6.10
# 2  44,793 Ratings  2,402 Reviews      NIL          128                 6.10
# 3   1,005 Ratings     41 Reviews        4          128                 6.56
# 4   1,005 Ratings     41 Reviews        4           64                 6.56
#
#         Camera                                        Description  \
# ...

# %%
df.shape
# Out:
# (984, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         984 non-null    object
#  1   Actual price         984 non-null    object
#  2   Discount price       984 non-null    object
#  3   Stars                984 non-null    float64
#  4   Rating               984 non-null    object
#  5   Reviews              984 non-null    object
#  6   RAM (GB)             984 non-null    object
#  7   Storage (GB)         984 non-null    object
#  8   Display Size (inch)  984 non-null    float64
#  9   Camera               908 non-null    object
#  10  Description          984 non-null    object
#  11  Link                 984 non-null    object
# dtypes: float64(2), object(10)
# memory usage: 92.4+ KB

# %%
df.isnull().sum()
# Out:
# Product Name            0
# Actual price            0
# Discount price          0
# Stars                   0
# Rating                  0
# Reviews                 0
# RAM (GB)                0
# Storage (GB)            0
# Display Size (inch)     0
# Camera                 76
# Description             0
# Link                    0
# dtype: int64

# %%
df
# Out:
#                            Product Name Actual price Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ..                                  ...          ...            ...    ...
# 979                        Kechaoda A27       ₹1,499           ₹967    4.0
# 980                        Kechaoda A27       ₹1,499           ₹975    4.0
# 981                        Kechaoda A27       ₹1,499           ₹975    4.0
# 982                        Kechaoda A27       ₹1,499           ₹930    4.0
# 983                        Kechaoda A27       ₹1,499           ₹967    4.0
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Product Name', 'Actual price', 'Discount price', 'Stars', 'Rating',
#        'Reviews', 'RAM (GB)', 'Storage (GB)', 'Display Size (inch)', 'Camera',
#        'Description', 'Link'],
#       dtype='object')

# %%
df['Product Name'].nunique()
# Out:
# 657

# %%
df
# Out:
#                            Product Name Actual price Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ..                                  ...          ...            ...    ...
# 979                        Kechaoda A27       ₹1,499           ₹967    4.0
# 980                        Kechaoda A27       ₹1,499           ₹975    4.0
# 981                        Kechaoda A27       ₹1,499           ₹975    4.0
# 982                        Kechaoda A27       ₹1,499           ₹930    4.0
# 983                        Kechaoda A27       ₹1,499           ₹967    4.0
#
# ...

# %%
df = df.drop_duplicates(subset="Product Name")

# %%
df
# Out:
#                            Product Name Actual price Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ..                                  ...          ...            ...    ...
# 971                        Kechaoda K33       ₹1,412         ₹1,064    4.0
# 973                        Kechaoda K28       ₹1,399         ₹1,260    4.0
# 974                        LAVA A3 vibe       ₹1,319         ₹1,212    4.2
# 975                        Kechaoda A26       ₹1,499           ₹930    4.0
# 978                        Kechaoda A27       ₹1,499           ₹967    4.0
#
# ...

# %%
df["Rating"] = df["Rating"].str.replace(" Ratings", "").str.replace(",", "")
# Out:
# C:\Users\matru\AppData\Local\Temp\ipykernel_10356\2677095242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Rating"] = df["Rating"].str.replace(" Ratings", "").str.replace(",", "")

# %%
df["Rating"] = df["Rating"].astype("int")
# Out:
# C:\Users\matru\AppData\Local\Temp\ipykernel_10356\2242547474.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Rating"] = df["Rating"].astype("int")

# %%
df
# Out:
#                            Product Name Actual price Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ..                                  ...          ...            ...    ...
# 971                        Kechaoda K33       ₹1,412         ₹1,064    4.0
# 973                        Kechaoda K28       ₹1,399         ₹1,260    4.0
# 974                        LAVA A3 vibe       ₹1,319         ₹1,212    4.2
# 975                        Kechaoda A26       ₹1,499           ₹930    4.0
# 978                        Kechaoda A27       ₹1,499           ₹967    4.0
#
# ...

# %%
df = df.rename(columns={"Reviews":"Overall_Reviews"})

# %%
df
# Out:
#                            Product Name Actual price Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ..                                  ...          ...            ...    ...
# 971                        Kechaoda K33       ₹1,412         ₹1,064    4.0
# 973                        Kechaoda K28       ₹1,399         ₹1,260    4.0
# 974                        LAVA A3 vibe       ₹1,319         ₹1,212    4.2
# 975                        Kechaoda A26       ₹1,499           ₹930    4.0
# 978                        Kechaoda A27       ₹1,499           ₹967    4.0
#
# ...

# %%
df["Overall_Reviews"]=df["Overall_Reviews"].str.replace("Reviews","").str.replace(",", "")

# %%
df
# Out:
#                            Product Name Actual price Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ..                                  ...          ...            ...    ...
# 971                        Kechaoda K33       ₹1,412         ₹1,064    4.0
# 973                        Kechaoda K28       ₹1,399         ₹1,260    4.0
# 974                        LAVA A3 vibe       ₹1,319         ₹1,212    4.2
# 975                        Kechaoda A26       ₹1,499           ₹930    4.0
# 978                        Kechaoda A27       ₹1,499           ₹967    4.0
#
# ...

# %%
df["Overall_Reviews"]  = df["Overall_Reviews"].astype("int")

# %%
df
# Out:
#                            Product Name Actual price Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ..                                  ...          ...            ...    ...
# 971                        Kechaoda K33       ₹1,412         ₹1,064    4.0
# 973                        Kechaoda K28       ₹1,399         ₹1,260    4.0
# 974                        LAVA A3 vibe       ₹1,319         ₹1,212    4.2
# 975                        Kechaoda A26       ₹1,499           ₹930    4.0
# 978                        Kechaoda A27       ₹1,499           ₹967    4.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 657 entries, 0 to 978
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         657 non-null    object
#  1   Actual price         657 non-null    object
#  2   Discount price       657 non-null    object
#  3   Stars                657 non-null    float64
#  4   Rating               657 non-null    int32
#  5   Overall_Reviews      657 non-null    int32
#  6   RAM (GB)             657 non-null    object
#  7   Storage (GB)         657 non-null    object
#  8   Display Size (inch)  657 non-null    float64
#  9   Camera               609 non-null    object
#  10  Description          657 non-null    object
#  11  Link                 657 non-null    object
# dtypes: float64(2), int32(2), object(8)
# memory usage: 61.6+ KB

# %%
df["Actual Price"] = df["Actual price"].str.replace("₹", "").str.replace(",", "")

# %%
df
# Out:
#                            Product Name Actual price Discount price  Stars  \
# 0       Apple iPhone 15 (Green, 128 GB)      ₹79,600        ₹65,999    4.6
# 1        Apple iPhone 15 (Blue, 128 GB)      ₹79,600        ₹65,999    4.6
# 2       Apple iPhone 15 (Black, 128 GB)      ₹79,600        ₹65,999    4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)      ₹19,999        ₹11,489    4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)      ₹16,999        ₹12,999    4.0
# ..                                  ...          ...            ...    ...
# 971                        Kechaoda K33       ₹1,412         ₹1,064    4.0
# 973                        Kechaoda K28       ₹1,399         ₹1,260    4.0
# 974                        LAVA A3 vibe       ₹1,319         ₹1,212    4.2
# 975                        Kechaoda A26       ₹1,499           ₹930    4.0
# 978                        Kechaoda A27       ₹1,499           ₹967    4.0
#
# ...

# %%
df.drop(columns=["Actual price","Link","Description"],inplace = True)

# %%
df
# Out:
#                            Product Name Discount price  Stars  Rating  \
# 0       Apple iPhone 15 (Green, 128 GB)        ₹65,999    4.6   44793
# 1        Apple iPhone 15 (Blue, 128 GB)        ₹65,999    4.6   44793
# 2       Apple iPhone 15 (Black, 128 GB)        ₹65,999    4.6   44793
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)        ₹11,489    4.0    1005
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)        ₹12,999    4.0    1005
# ..                                  ...            ...    ...     ...
# 971                        Kechaoda K33         ₹1,064    4.0    9879
# 973                        Kechaoda K28         ₹1,260    4.0    4073
# 974                        LAVA A3 vibe         ₹1,212    4.2   21425
# 975                        Kechaoda A26           ₹930    4.0   22244
# 978                        Kechaoda A27           ₹967    4.0   11022
#
#      Overall_Reviews RAM (GB) Storage (GB)  Display Size (inch)       Camera  \
# ...

# %%
df["Discount price"] = df["Discount price"].str.replace("₹", "").str.replace(",", "")

# %%
df
# Out:
#                            Product Name Discount price  Stars  Rating  \
# 0       Apple iPhone 15 (Green, 128 GB)          65999    4.6   44793
# 1        Apple iPhone 15 (Blue, 128 GB)          65999    4.6   44793
# 2       Apple iPhone 15 (Black, 128 GB)          65999    4.6   44793
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)          11489    4.0    1005
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)          12999    4.0    1005
# ..                                  ...            ...    ...     ...
# 971                        Kechaoda K33           1064    4.0    9879
# 973                        Kechaoda K28           1260    4.0    4073
# 974                        LAVA A3 vibe           1212    4.2   21425
# 975                        Kechaoda A26            930    4.0   22244
# 978                        Kechaoda A27            967    4.0   11022
#
#      Overall_Reviews RAM (GB) Storage (GB)  Display Size (inch)       Camera  \
# ...

# %%
df.rename(columns={"Stars":"Stars(out of 5)"},inplace = True)

# %%
df
# Out:
#                            Product Name Discount price  Stars(out of 5)  \
# 0       Apple iPhone 15 (Green, 128 GB)          65999              4.6
# 1        Apple iPhone 15 (Blue, 128 GB)          65999              4.6
# 2       Apple iPhone 15 (Black, 128 GB)          65999              4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)          11489              4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)          12999              4.0
# ..                                  ...            ...              ...
# 971                        Kechaoda K33           1064              4.0
# 973                        Kechaoda K28           1260              4.0
# 974                        LAVA A3 vibe           1212              4.2
# 975                        Kechaoda A26            930              4.0
# 978                        Kechaoda A27            967              4.0
#
#      Rating  Overall_Reviews RAM (GB) Storage (GB)  Display Size (inch)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 657 entries, 0 to 978
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         657 non-null    object
#  1   Discount price       657 non-null    int32
#  2   Stars(out of 5)      657 non-null    float64
#  3   Rating               657 non-null    int32
#  4   Overall_Reviews      657 non-null    int32
#  5   RAM (GB)             657 non-null    object
#  6   Storage (GB)         657 non-null    object
#  7   Display Size (inch)  657 non-null    float64
#  8   Camera               609 non-null    object
#  9   Actual Price         657 non-null    object
# dtypes: float64(2), int32(3), object(5)
# memory usage: 48.8+ KB

# %%
df["Discount price"] = pd.to_numeric(df["Discount price"].str.replace("₹", "").str.replace(",", ""), errors='coerce')

# %%
df["Discount price"] = df["Discount price"].fillna(0.0)

# %%
df["Discount price"] = df["Discount price"].astype("int")

# %%
df["Actual price"] = pd.to_numeric(df["Actual Price"].str.replace("₹", "").str.replace(",", ""), errors='coerce')

# %%
df["Actual price"] =df["Actual price"] .fillna(0.0)

# %%
df["Actual price"]  = df["Actual price"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 657 entries, 0 to 978
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         657 non-null    object
#  1   Discount price       657 non-null    int32
#  2   Stars(out of 5)      657 non-null    float64
#  3   Rating               657 non-null    int32
#  4   Overall_Reviews      657 non-null    int32
#  5   RAM (GB)             657 non-null    object
#  6   Storage (GB)         657 non-null    object
#  7   Display Size (inch)  657 non-null    float64
#  8   Camera               609 non-null    object
#  9   Actual Price         657 non-null    object
#  10  Actual price         657 non-null    int32
# dtypes: float64(2), int32(4), object(5)
# memory usage: 51.3+ KB

# %%
df.drop(columns="Actual Price",inplace=True)

# %%
df
# Out:
#                            Product Name  Discount price  Stars(out of 5)  \
# 0       Apple iPhone 15 (Green, 128 GB)           65999              4.6
# 1        Apple iPhone 15 (Blue, 128 GB)           65999              4.6
# 2       Apple iPhone 15 (Black, 128 GB)           65999              4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)           11489              4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)           12999              4.0
# ..                                  ...             ...              ...
# 971                        Kechaoda K33            1064              4.0
# 973                        Kechaoda K28            1260              4.0
# 974                        LAVA A3 vibe            1212              4.2
# 975                        Kechaoda A26             930              4.0
# 978                        Kechaoda A27             967              4.0
#
#      Rating  Overall_Reviews RAM (GB) Storage (GB)  Display Size (inch)  \
# ...

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#                            Product Name  Discount price  Stars(out of 5)  \
# 0       Apple iPhone 15 (Green, 128 GB)           65999              4.6
# 1        Apple iPhone 15 (Blue, 128 GB)           65999              4.6
# 2       Apple iPhone 15 (Black, 128 GB)           65999              4.6
# 3    OnePlus N20 SE (JADE WAVE, 128 GB)           11489              4.0
# 4    OnePlus N20 SE (BLUE OASIS, 64 GB)           12999              4.0
# ..                                  ...             ...              ...
# 652                        Kechaoda K33            1064              4.0
# 653                        Kechaoda K28            1260              4.0
# 654                        LAVA A3 vibe            1212              4.2
# 655                        Kechaoda A26             930              4.0
# 656                        Kechaoda A27             967              4.0
#
#      Rating  Overall_Reviews RAM (GB) Storage (GB)  Display Size (inch)  \
# ...

# %%
df[df["RAM (GB)"]=="NIL"]
# Out:
#                                           Product Name  Discount price  \
# 17   itel it5027 6.1cm Screen,1200mAh Battery Wirel...            1177
# 21               Apple iPhone 15 Plus (Yellow, 128 GB)           73999
# 27   LAVA A3 Vibe DS Keypad Mobile| 1750 mAh Batter...            1208
# 44   LAVA A1 Josh BOL Keypad Mobile|1000 mAh Batter...             960
# 57   Nokia 105 Single SIM, Keypad Mobile Phone with...            1449
# ..                                                 ...             ...
# 652                                       Kechaoda K33            1064
# 653                                       Kechaoda K28            1260
# 654                                       LAVA A3 vibe            1212
# 655                                       Kechaoda A26             930
# 656                                       Kechaoda A27             967
#
#      Stars(out of 5)  Rating  Overall_Reviews RAM (GB) Storage (GB)  \
# ...

# %%
df[df["Product Name"].str.startswith("Apple iPhone 12")].index.to_list()
# Out:
# [649, 650, 651]

# %%
df.iloc[[599, 600, 601],5] = [4,4,4]

# %%
df[df["Product Name"].str.startswith("Apple iPhone 13")].index.to_list()
# Out:
# [637, 643, 644, 645, 646]

# %%
df.iloc[[590, 593, 594, 595, 596],5] = [4,4,4,4,4]

# %%
df[df["Product Name"].str.startswith("Apple iPhone 13")].index.to_list()
# Out:
# [637, 643, 644, 645, 646]

# %%
df[df["Product Name"].str.startswith("Apple iPhone 14 Plus")].index.to_list()
# Out:
# [117, 311, 510, 511, 542, 543]

# %%
df.iloc[[106, 282, 470, 471, 500, 501],5] = 6

# %%
df1 = df[df["Product Name"].str.startswith("Apple iPhone 15 Plus")].index.to_list()

# %%
df[df["RAM (GB)"]=="NIL"]
# Out:
#                                           Product Name  Discount price  \
# 17   itel it5027 6.1cm Screen,1200mAh Battery Wirel...            1177
# 21               Apple iPhone 15 Plus (Yellow, 128 GB)           73999
# 27   LAVA A3 Vibe DS Keypad Mobile| 1750 mAh Batter...            1208
# 44   LAVA A1 Josh BOL Keypad Mobile|1000 mAh Batter...             960
# 57   Nokia 105 Single SIM, Keypad Mobile Phone with...            1449
# ..                                                 ...             ...
# 652                                       Kechaoda K33            1064
# 653                                       Kechaoda K28            1260
# 654                                       LAVA A3 vibe            1212
# 655                                       Kechaoda A26             930
# 656                                       Kechaoda A27             967
#
#      Stars(out of 5)  Rating  Overall_Reviews RAM (GB) Storage (GB)  \
# ...

# %%
df1
# Out:
# [21, 509, 562, 573, 623]

# %%
df1[df1["Rating"]=="NIL"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df1[df1["Rating"]=="NIL"]
#
# TypeError: list indices must be integers or slices, not str

# %%
df.iloc[[19, 469, 519, 530, 578], 5] = 6

# %%
df2 = df[df["Product Name"].str.startswith("Apple iPhone 14 ")]

# %%
df1[df1['RAM (GB)']=='NIL'].index.to_list()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df1[df1['RAM (GB)']=='NIL'].index.to_list()
#
# TypeError: list indices must be integers or slices, not str

# %%
df.iloc[[0, 1, 2, 307, 362, 363, 400, 498], 5] = 4

# %%
df2[df2["RAM (GB)"]=="NIL"].index.to_list()
# Out:
# [117, 186, 296, 311, 510, 511, 515, 542, 543, 555, 611]

# %%
df.iloc[[170, 267, 474, 513, 566],5]=4

# %%
df[df["RAM (GB)"]=="NIL"].index.to_list()
# Out:
# [17,
#  21,
#  27,
#  44,
#  57,
#  58,
#  65,
#  67,
#  69,
#  81,
#  92,
#  104,
#  105,
#  117,
#  124,
#  148,
#  149,
#  151,
#  153,
#  165,
#  171,
#  186,
#  199,
#  208,
#  211,
#  222,
#  224,
#  226,
#  236,
#  243,
#  245,
#  249,
#  269,
#  274,
#  296,
#  311,
#  321,
#  322,
#  324,
#  338,
#  341,
#  347,
#  357,
#  377,
#  396,
#  397,
#  428,
#  435,
#  442,
#  463,
#  466,
#  488,
#  502,
#  504,
#  509,
#  510,
#  511,
#  512,
#  515,
#  533,
#  540,
#  542,
#  543,
#  555,
#  556,
#  562,
#  573,
#  591,
#  611,
#  623,
#  634,
#  635,
#  637,
#  638,
#  639,
#  642,
#  643,
#  644,
#  645,
#  646,
#  649,
#  650,
#  651,
#  652,
#  653,
#  654,
#  655,
#  656]

# %%
df.iloc[[59, 73, 136, 139, 293, 343, 427, 602],5] = 0

# %%
df["RAM (GB)"].unique()
# Out:
# array([4, '4', '8', '6', '12', '16', 'NIL', 6, '3', '2', 0, '32', '46875'],
#       dtype=object)

# %%
df["RAM (GB)"] = df["RAM (GB)"].astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 df["RAM (GB)"] = df["RAM (GB)"].astype("int")
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %%
df

# %%
df["Storage (GB)"] = df["Storage (GB)"].astype("int")

# %%
df

# %%
df.info()

# %%
df["Camera"].unique()

# %%
df["Camera"] = df["Camera"].str.replace("|","+")

# %%
df["Camera"].fillna("0MP",inplace = True)

# %%
df[df["Camera"]=="0MP"]

# %%
df[df["Product Name"].str.startswith("Infinix SMART 8 HD")]

# %%
df.iloc[[18,193,324,579],8] = "13MP + AI Lens"

# %%
df[df["Camera"]=="0MP"]

# %%
df3 = df[df["Product Name"].str.startswith("Infinix SMART 8")]

# %%
df3[df3["Camera"]=='0MP'].index

# %%
df.iloc[[51, 52, 322, 323, 397, 398, 436, 437],8] = "50MP + AI Lens"

# %%
df[df["Camera"]=="0MP"]

# %%
df[df["Product Name"].str.startswith("Infinix Smart 8 Plus")].index

# %%
df.iloc[[453, 527, 528],7] = "50MP + AI Lens"
# Out:
# C:\Users\matru\AppData\Local\Temp\ipykernel_10356\817266042.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '50MP + AI Lens' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.iloc[[453, 527, 528],7] = "50MP + AI Lens"

# %%
df.iloc[[453, 527, 528],7]
# Out:
# 453    50MP + AI Lens
# 527    50MP + AI Lens
# 528    50MP + AI Lens
# Name: Display Size (inch), dtype: object

# %%
df[df["Camera"]=="0MP"]

# %%
df[df["Product Name"].str.startswith("Infinix HOT 30i")].index

# %%
df.iloc[[61, 434, 435, 555, 556, 586, 587],8] = "50MP + AI Lens"

# %%
df.iloc[[61, 434, 435, 555, 556, 586, 587],7]
# Out:
# 61     6.79
# 434    6.78
# 435    6.10
# 555    6.10
# 556    2.40
# 586    6.74
# 587    6.70
# Name: Display Size (inch), dtype: float64

# %%
df[df["Product Name"].str.startswith("Infinix HOT 40i")].index

# %%
df.iloc[[63, 183, 505, 509],8] = "50MP + AI Lens"

# %%
df[df["Camera"]=="0MP"]

# %%
df[df["Product Name"].str.startswith("Infinix Note 30 5G")].index

# %%
df.iloc[[461, 462, 494],8] = "108MP + 2MP + AI Lens"

# %%
df[df["Product Name"].str.startswith("Infinix HOT 30 5G")].index

# %%
df.iloc[[325, 490],8] = "50MP + AI Lens"

# %%
df[df["Camera"]=="0MP"]
# Out:
# Empty DataFrame
# Columns: [Product Name, Discount price, Stars(out of 5), Rating, Overall_Reviews, RAM (GB), Storage (GB), Display Size (inch), Camera, Actual price]
# Index: []

# %%
df.iloc[472,8] = "50MP"

# %%
df.iloc[472,7]
# Out:
# 6.6

# %%
df[df["Camera"]=="0MP"]

# %%
df[df["RAM (GB)"]==0]

# %%
df

# %%
cleaned_df = df.copy()

# %%
cleaned_df

# %%
cleaned_df.info()

# %%
high_level_phones = df[df["Discount price"]>30000]

# %%
mid_level_phones = df[(df["Discount price"]>=10000) & (df["Discount price"]<=30000)]

# %%
low_level_phones = df[df["Discount price"]<10000]

# %%
high_level_phones.describe()

# %%
high_level_phones[high_level_phones["Actual Price"]==0]

# %%
mid_level_phones.describe()

# %%
mid_level_phones[mid_level_phones["Actual Price"]==0]

# %%
low_level_phones.describe()

# %%
low_level_phones[low_level_phones["Actual Price"]==0]

# %%
high_level_phones.info()

# %%
df

# %%
cleaned_df

# %%
cleaned_df
